# %%
import pandas as pd
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
stop_words = set(stopwords.words('english'))
import wordsegment as ws 
ws.load() 
import random
import math
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import NearestCentroid
from sklearn import svm
from sklearn.metrics import accuracy_score,recall_score
import joblib

# %%
def clean_tweets(text):  
    text = text.lower()
    text_pattern = re.compile('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]|))+')
    text = text_pattern.sub('', text)
    emoji = re.compile("["
                        u"\U0001F600-\U0001FFFF"   #EMOJIS
                        u"\U0001F300-\U0001F5FF"   #Symbols and Pictographs
                        u"\U0001F680-\U0001F6FF"   #map symbols
                        u"\U0001F1E0-\U0001F1FF"   #flags
                        u"\U00002702-\U000027B0"
                        u"\U000024C2-\U0001F251"
                        "]+", flags=re.UNICODE)
    text = emoji.sub(r'', text)
    text = re.sub(r'@[a-z0-9]+','',text)
   # text = re.sub(r'#', '', text)
    text = re.sub(r"i'm", "i am", text)
    text = re.sub(r"he's", "he is", text)
    text = re.sub(r"she's", "she is", text)
    text = re.sub(r"that's", "that is", text)
    text = re.sub(r"this's", "this is", text)
    text = re.sub(r"what's", "what is", text)
    text = re.sub(r"where's", "where is", text)
    text = re.sub(r"\'ll", "will", text)
    text = re.sub(r"\'ve", "have", text)
    text = re.sub(r"\'m", "am", text)
    text = re.sub(r"\'d", "would", text)
    text = re.sub(r"\'re", "are", text)
    text = re.sub(r"won't", "will not", text)
    text = re.sub(r"don't", "do not", text)
    text = re.sub(r"didn't", "did not", text)
    text = re.sub(r"can't", "can not", text)
    text = re.sub(r"it's", "it is", text)
    text = re.sub(r"couldn't", "could not", text)
    text = re.sub(r"haven't", "have not", text)
    text = re.sub(r'rt[\s]+', '', text)

    text = re.sub(r"[,.\"!#$%^&*(){}?/;'~:<>+=-]", "", text)
    
    tokens = word_tokenize(text)
    
    text = [ws.clean(w) for w in text if len(ws.clean(w)) > 0]
    text = [ws.segment(w)[0] for w in text]   #segmentation
    
    stop_words = set(stopwords.words("english"))
    stop_words.discard("not")
    table = str.maketrans('','',string.punctuation)
    stripped = [w.translate(table) for w in tokens]
    words = [word for word in stripped if word.isalpha()]

    words = [w for w in words if not w in stop_words]
    words = ' '.join(words)
        
    return words

# %%
df=pd.read_csv("tweets_cleaned.csv")
print(len(df))

X_train, X_val, y_train, y_val = train_test_split(df['text_cleaned'], df['class'] , test_size=0.2, stratify = df['class'],random_state=0)

param = [2,4,6,8,10,100,1000]
kernel = ['linear','rbf','poly','sigmoid','precomputed']
gamma = [0.01,0.05,0.09,0.5,0.9,5,10,100]

for c in param:
    for g in gamma:
        print()
        print('C:',c,'gamma:',g,':')
        model=make_pipeline(TfidfVectorizer(),svm.SVC(C = c, kernel = 'rbf', gamma = g))

        model.fit(X_train, y_train)

        labels_train = model.predict(X_train)
        labels_val = model.predict(X_val)

        print("Training Accuracy:",accuracy_score(y_train, labels_train)*100)
        print("Validation Accuracy:",accuracy_score(y_val, labels_val)*100)
        print(recall_score(y_train, labels_train, average='weighted'))
        print(recall_score(y_val, labels_val, average='weighted'))

        def predict(s,model = model):
            print(model.predict([s]))

        text = clean_tweets("yogi")
        print(text)
        predict(text)
# Out:
# 19569
#
# C: 2 gamma: 0.01 :
# Training Accuracy: 62.216544235068675
# Validation Accuracy: 61.39499233520696
# 0.6221654423506867
# 0.6139499233520695
# yogi
# ['politics']
#
# C: 2 gamma: 0.05 :
# Training Accuracy: 85.72979878633025
# Validation Accuracy: 80.35258048032703
# 0.8572979878633025
# 0.8035258048032703
# yogi
# ['politics']
#
# C: 2 gamma: 0.09 :
# Training Accuracy: 91.51069945704248
# Validation Accuracy: 83.41849770056209
# 0.9151069945704248
# 0.8341849770056209
# yogi
# ['politics']
#
# C: 2 gamma: 0.5 :
# Training Accuracy: 99.75726604918556
# Validation Accuracy: 86.79100664282065
# 0.9975726604918557
# 0.8679100664282065
# yogi
# ['politics']
#
# C: 2 gamma: 0.9 :
# Training Accuracy: 99.97444905780901
# Validation Accuracy: 87.19979560551864
# 0.9997444905780901
# 0.8719979560551865
# yogi
# ['politics']
#
# C: 2 gamma: 5 :
# Training Accuracy: 99.9872245289045
# Validation Accuracy: 58.38017373530915
# 0.9998722452890451
# 0.5838017373530915
# yogi
# ['education']
#
# C: 2 gamma: 10 :
# Training Accuracy: 99.9872245289045
# Validation Accuracy: 41.977516607051605
# 0.9998722452890451
# 0.41977516607051607
# yogi
# ['education']
#
# C: 2 gamma: 100 :
# Training Accuracy: 99.9872245289045
# Validation Accuracy: 35.232498722534494
# 0.9998722452890451
# 0.35232498722534494
# yogi
# ['education']
#
# C: 4 gamma: 0.01 :
# Training Accuracy: 75.92462472053657
# Validation Accuracy: 73.81195707715892
# 0.7592462472053657
# 0.7381195707715892
# yogi
# ['politics']
#
# C: 4 gamma: 0.05 :
# Training Accuracy: 92.77547109549664
# Validation Accuracy: 83.95503321410321
# 0.9277547109549664
# 0.8395503321410321
# yogi
# ['politics']
#
# C: 4 gamma: 0.09 :
# Training Accuracy: 96.7358671351006
# Validation Accuracy: 85.13030148185999
# 0.9673586713510061
# 0.8513030148185999
# yogi
# ['politics']
#
# C: 4 gamma: 0.5 :
# Training Accuracy: 99.97444905780901
# Validation Accuracy: 86.50996423096576
# 0.9997444905780901
# 0.8650996423096576
# yogi
# ['politics']
#
# C: 4 gamma: 0.9 :
# Training Accuracy: 99.9872245289045
# Validation Accuracy: 87.19979560551864
# 0.9998722452890451
# 0.8719979560551865
# yogi
# ['politics']
#
# C: 4 gamma: 5 :
# Training Accuracy: 99.9872245289045
# Validation Accuracy: 58.38017373530915
# 0.9998722452890451
# 0.5838017373530915
# yogi
# ['education']
#
# C: 4 gamma: 10 :
# Training Accuracy: 99.9872245289045
# Validation Accuracy: 41.977516607051605
# 0.9998722452890451
# 0.41977516607051607
# yogi
# ['education']
#
# C: 4 gamma: 100 :
# Training Accuracy: 99.9872245289045
# Validation Accuracy: 35.232498722534494
# 0.9998722452890451
# 0.35232498722534494
# yogi
# ['education']
#
# C: 6 gamma: 0.01 :
# Training Accuracy: 80.83679335675504
# Validation Accuracy: 77.59325498211548
# 0.8083679335675503
# 0.7759325498211548
# yogi
# ['politics']
#
# C: 6 gamma: 0.05 :
# Training Accuracy: 95.68189076972213
# Validation Accuracy: 84.97700562084823
# 0.9568189076972213
# 0.8497700562084823
# yogi
# ['politics']
#
# C: 6 gamma: 0.09 :
# Training Accuracy: 98.30086234429895
# Validation Accuracy: 85.89678078691875
# 0.9830086234429894
# 0.8589678078691876
# yogi
# ['politics']
#
# C: 6 gamma: 0.5 :
# Training Accuracy: 99.9872245289045
# Validation Accuracy: 86.45886561062851
# 0.9998722452890451
# 0.8645886561062851
# yogi
# ['politics']
#
# C: 6 gamma: 0.9 :
# Training Accuracy: 99.9872245289045
# Validation Accuracy: 87.19979560551864
# 0.9998722452890451
# 0.8719979560551865
# yogi
# ['politics']
#
# C: 6 gamma: 5 :
# Training Accuracy: 99.9872245289045
# Validation Accuracy: 58.38017373530915
# 0.9998722452890451
# 0.5838017373530915
# yogi
# ['education']
#
# C: 6 gamma: 10 :
# Training Accuracy: 99.9872245289045
# Validation Accuracy: 41.977516607051605
# 0.9998722452890451
# 0.41977516607051607
# yogi
# ['education']
#
# C: 6 gamma: 100 :
# Training Accuracy: 99.9872245289045
# Validation Accuracy: 35.232498722534494
# 0.9998722452890451
# 0.35232498722534494
# yogi
# ['education']
#
# C: 8 gamma: 0.01 :
# Training Accuracy: 83.89013094857873
# Validation Accuracy: 79.6116504854369
# 0.8389013094857873
# 0.7961165048543689
# yogi
# ['politics']
#
# C: 8 gamma: 0.05 :
# Training Accuracy: 97.26604918556372
# Validation Accuracy: 85.334695963209
# 0.9726604918556372
# 0.85334695963209
# yogi
# ['politics']
#
# C: 8 gamma: 0.09 :
# Training Accuracy: 99.13765570105397
# Validation Accuracy: 86.20337250894225
# 0.9913765570105397
# 0.8620337250894226
# yogi
# ['politics']
#
# C: 8 gamma: 0.5 :
# Training Accuracy: 99.9872245289045
# Validation Accuracy: 86.45886561062851
# 0.9998722452890451
# 0.8645886561062851
# yogi
# ['politics']
#
# C: 8 gamma: 0.9 :
# Training Accuracy: 99.9872245289045
# Validation Accuracy: 87.19979560551864
# 0.9998722452890451
# 0.8719979560551865
# yogi
# ['politics']
#
# C: 8 gamma: 5 :
# Training Accuracy: 99.9872245289045
# Validation Accuracy: 58.38017373530915
# 0.9998722452890451
# 0.5838017373530915
# yogi
# ['education']
#
# C: 8 gamma: 10 :
# Training Accuracy: 99.9872245289045
# Validation Accuracy: 41.977516607051605
# 0.9998722452890451
# 0.41977516607051607
# yogi
# ['education']
#
# C: 8 gamma: 100 :
# Training Accuracy: 99.9872245289045
# Validation Accuracy: 35.232498722534494
# 0.9998722452890451
# 0.35232498722534494
# yogi
# ['education']
#
# C: 10 gamma: 0.01 :
# Training Accuracy: 86.22804215905462
# Validation Accuracy: 80.65917220235053
# 0.8622804215905462
# 0.8065917220235054
# yogi
# ['politics']
#
# C: 10 gamma: 0.05 :
# Training Accuracy: 97.98786330245927
# Validation Accuracy: 85.87123147675013
# 0.9798786330245928
# 0.8587123147675013
# yogi
# ['politics']
#
# C: 10 gamma: 0.09 :
# Training Accuracy: 99.53369530501436
# Validation Accuracy: 86.17782319877362
# 0.9953369530501437
# 0.8617782319877363
# yogi
# ['politics']
#
# C: 10 gamma: 0.5 :
# Training Accuracy: 99.9872245289045
# Validation Accuracy: 86.45886561062851
# 0.9998722452890451
# 0.8645886561062851
# yogi
# ['politics']
#
# C: 10 gamma: 0.9 :
# Training Accuracy: 99.9872245289045
# Validation Accuracy: 87.19979560551864
# 0.9998722452890451
# 0.8719979560551865
# yogi
# ['politics']
#
# C: 10 gamma: 5 :
# Training Accuracy: 99.9872245289045
# Validation Accuracy: 58.38017373530915
# 0.9998722452890451
# 0.5838017373530915
# yogi
# ['education']
#
# C: 10 gamma: 10 :
# Training Accuracy: 99.9872245289045
# Validation Accuracy: 41.977516607051605
# 0.9998722452890451
# 0.41977516607051607
# yogi
# ['education']
#
# C: 10 gamma: 100 :
# Training Accuracy: 99.9872245289045
# Validation Accuracy: 35.232498722534494
# 0.9998722452890451
# 0.35232498722534494
# yogi
# ['education']
#
# C: 100 gamma: 0.01 :
# Training Accuracy: 99.57202171830086
# Validation Accuracy: 85.99897802759325
# 0.9957202171830086
# 0.8599897802759325
# yogi
# ['politics']
#
# C: 100 gamma: 0.05 :
# Training Accuracy: 99.9872245289045
# Validation Accuracy: 85.43689320388349
# 0.9998722452890451
# 0.8543689320388349
# yogi
# ['politics']
#
# C: 100 gamma: 0.09 :
# Training Accuracy: 99.9872245289045
# Validation Accuracy: 85.71793561573837
# 0.9998722452890451
# 0.8571793561573837
# yogi
# ['politics']
#
# C: 100 gamma: 0.5 :
# Training Accuracy: 99.9872245289045
# Validation Accuracy: 86.45886561062851
# 0.9998722452890451
# 0.8645886561062851
# yogi
# ['politics']
#
# C: 100 gamma: 0.9 :
# Training Accuracy: 99.9872245289045
# Validation Accuracy: 87.19979560551864
# 0.9998722452890451
# 0.8719979560551865
# yogi
# ['politics']
#
# C: 100 gamma: 5 :
# Training Accuracy: 99.9872245289045
# Validation Accuracy: 58.38017373530915
# 0.9998722452890451
# 0.5838017373530915
# yogi
# ['education']
#
# C: 100 gamma: 10 :
# Training Accuracy: 99.9872245289045
# Validation Accuracy: 41.977516607051605
# 0.9998722452890451
# 0.41977516607051607
# yogi
# ['education']
#
# C: 100 gamma: 100 :
# Training Accuracy: 99.9872245289045
# Validation Accuracy: 35.232498722534494
# 0.9998722452890451
# 0.35232498722534494
# yogi
# ['education']
#
# C: 1000 gamma: 0.01 :
# Training Accuracy: 99.9872245289045
# Validation Accuracy: 85.15585079202862
# 0.9998722452890451
# 0.8515585079202862
# yogi
# ['politics']
#
# C: 1000 gamma: 0.05 :
# Training Accuracy: 99.9872245289045
# Validation Accuracy: 85.41134389371487
# 0.9998722452890451
# 0.8541134389371488
# yogi
# ['politics']
#
# C: 1000 gamma: 0.09 :
# Training Accuracy: 99.9872245289045
# Validation Accuracy: 85.71793561573837
# 0.9998722452890451
# 0.8571793561573837
# yogi
# ['politics']
#
# C: 1000 gamma: 0.5 :
# Training Accuracy: 99.9872245289045
# Validation Accuracy: 86.45886561062851
# 0.9998722452890451
# 0.8645886561062851
# yogi
# ['politics']
#
# C: 1000 gamma: 0.9 :
# Training Accuracy: 99.9872245289045
# Validation Accuracy: 87.19979560551864
# 0.9998722452890451
# 0.8719979560551865
# yogi
# ['politics']
#
# C: 1000 gamma: 5 :
# Training Accuracy: 99.9872245289045
# Validation Accuracy: 58.38017373530915
# 0.9998722452890451
# 0.5838017373530915
# yogi
# ['education']
#
# C: 1000 gamma: 10 :
# Training Accuracy: 99.9872245289045
# Validation Accuracy: 41.977516607051605
# 0.9998722452890451
# 0.41977516607051607
# yogi
# ['education']
#
# C: 1000 gamma: 100 :
# Training Accuracy: 99.9872245289045
# Validation Accuracy: 35.232498722534494
# 0.9998722452890451
# 0.35232498722534494
# yogi
# ['education']
